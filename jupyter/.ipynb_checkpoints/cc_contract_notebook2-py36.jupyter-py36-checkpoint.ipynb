# %%
#!pip install ibm_watson
#!pip install ibm_cloud_sdk_core

# %%
import os
import json
from os.path import abspath
from ibm_watson import CompareComplyV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
authenticator = IAMAuthenticator('wHYGkVKD_3bO7hUudbf-gOHbt2zpbv9o3QURvFaln2jY')
compare_comply = CompareComplyV1(
    version='2018-10-15',
    authenticator=authenticator
)

compare_comply.set_service_url('https://gateway.watsonplatform.net/compare-comply/api')

with open(abspath(os.environ['DSX_PROJECT_DIR'] + '/datasets/Contract1_Standard.doc'), 'rb') as file1, open(abspath(os.environ['DSX_PROJECT_DIR'] + '/datasets/Contract1.doc'), 'rb') as file2:
    result = compare_comply.compare_documents(file1, file2).get_result()
print(json.dumps(result, indent=2))
# Out:
# {
#   "model_version": "1.2.1",
#   "documents": [
#     {
# ...

# %%
type(result)
# Out:
# dict
